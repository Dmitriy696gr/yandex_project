# %% [markdown]
# # Описание проекта

# %% [markdown]
# ### Постановка задачи:
#
# Отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# ### Этапы выполнения:
# 1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 2.
# В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца
# 3.
# Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.

# %% [markdown]
# Для выполнения задачи  руководством был сформирован следующий подход решения:
#
# 1. Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
#
#
# 2. Нужно собрать данные по клиентам по следующим группам:
# - Признаки, которые описывают коммуникацию сотрудников компании с клиентом;
# - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто;
# - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине;
# - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.

# %% [markdown]
# На диаграмме Исикавы представлены группы признаков
#
# ![](https://pictures.s3.yandex.net/resources/image_1695485033.png)

# %% [markdown]
# # Описание данных

# %% [markdown]
# **market_file.csv** - таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
# - **id** — номер покупателя в корпоративной базе данных.
# - **Покупательская активность** — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - **Тип сервиса** — уровень сервиса, например «премиум» и «стандарт».
# - **Разрешить сообщать** — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - **Маркет_актив_6_мес** — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - **Маркет_актив_тек_мес** — количество маркетинговых коммуникаций в текущем месяце.
# - **Длительность** — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - **Акционные_покупки** — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - **Популярная_категория** — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - **Средний_просмотр_категорий_за_визит** — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - **Неоплаченные_продукты_штук_квартал** — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - **Ошибка_сервиса** — число сбоев, которые коснулись покупателя во время посещения сайта.
# - **Страниц_за_визит** — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %% [markdown]
# **market_money.csv** -таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - **id** — номер покупателя в корпоративной базе данных.
# - **Период** — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# - **Выручка** — сумма выручки за период.

# %% [markdown]
# **market_time.csv** -таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - **id** — номер покупателя в корпоративной базе данных.
# - **Период** — название периода, во время которого зафиксировано общее время.
# - **минут** — значение времени, проведённого на сайте, в минутах.

# %% [markdown]
# **money.csv** -таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - **id** — номер покупателя в корпоративной базе данных.
# - **Прибыль** — значение прибыли.

# %% [markdown]
# # Рекомендации к выполнению проекта

# %% [markdown]
# Решать задачу вам нужно в два этапа:
#
# 1. Разработайте модель, которая предскажет вероятность снижения покупательской активности.
# 2. Выделите сегмент покупателей, проанализируйте его и предложите, как увеличить его покупательскую активность. Используйте данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся). По желанию вы можете проанализировать больше одного сегмента.
#
# Ниже несколько примеров сегментов, но вы также можете выделить свой:
#
# - Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# - Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
# - Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
# - Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Импорты всех необходимых библиотек и классов.

# %%
pip install imbalanced-learn -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install shap -q

# %%
# !pip install phik -q

# %%
# !pip install matplotlib==3.7.1 -q

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import warnings
import scipy.stats as st
import random
import shap

from phik import phik_matrix


from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, OrdinalEncoder, LabelEncoder, PolynomialFeatures
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (r2_score, mean_absolute_error, mean_squared_error,
                             accuracy_score, recall_score, precision_score,
                             confusion_matrix, precision_recall_curve,
                             f1_score, fbeta_score, roc_curve, RocCurveDisplay, roc_auc_score)
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import RandomUnderSampler


from sklearn.inspection import permutation_importance
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest, f_classif

# %% [markdown]
# #### Пользовательские функции ####

# %%
# Чекаем уникальные значения, чтобы определить дубликаты
def check_unique_values(data, columns):
    for column in columns:
        unique_values = data[column].unique()
        for value in unique_values:
            print(value)
        print()

# %%
# Меняем типы данных в датафреймах
def change_column_types(data, column_types):
    for column, data_type in column_types.items():
              data[column] = data[column].astype(data_type)

# %%
# Строим пироги и чекаем клиентов по кат признакам
def plot_activity_distribution(data, id_column, activity_columns):
    for column in activity_columns:
        activity_counts = data[column].value_counts()  

        plt.figure(figsize=(6, 6))
        plt.pie(activity_counts, labels=activity_counts.index, autopct='%1.1f%%')
        plt.title(f'Распределение в колонке {column} по {id_column}')
        plt.axis('equal')
        plt.show()

# %%
# строим ящики с усами и гистограмму. На самом деле эту функцию скоммуниздил из интернета ибо она очень красиво рисует графики. 
# у меня они были более страшные и функця была очень очеьн грамоздкая. Извините) 
def chart_hist(df, col, target):
    sns.set()
    f, axes = plt.subplots(1, 2, figsize=(14, 6))
    axes[0].set_title(f'Гистограмма для {col}', fontsize=10)
    axes[0].set_ylabel('Количество', fontsize=12)
    if target != None:
        sns.histplot(df, bins=25, kde=True, ax=axes[0], hue=target, x=col)
    else:
        sns.histplot(df, bins=25, kde=True,  ax=axes[0], x=col)
    axes[1].set_title(f'График ящик с усами для {col}', fontsize=10)
    sns.boxplot(data=df, ax=axes[1], y=col, color='white')
    axes[1].set_ylabel(col, fontsize=12)
    plt.show()

# %%
def scatplt(data, x, hue):
    sns.relplot(data=data, x=x, y='вероятность_снижения', hue=hue)
    plt.title('Зависимость покупательской активности от ' + x + ', в зависимости от ' + hue + ' и ')
    plt.xlabel(x)
    plt.ylabel('Вероятность сниженя')
    plt.show()

# %%
def chart_hist_(df, col, target, xlabel_rotation=0):
    sns.set()
    f, axes = plt.subplots(1, 1, figsize=(14, 6))
    axes.set_title(f'Гистограмма для {col}', fontsize=10)
    axes.set_ylabel('Количество', fontsize=12)
    plt.xticks(rotation=xlabel_rotation)  # Установка наклона подписей по оси x
    if target != None:
        sns.histplot(df, bins=25, kde=True, ax=axes, hue=target, x=col)
    else:
        sns.histplot(df, bins=25, kde=True, ax=axes, x=col)
    plt.show()

# %% [markdown]
# - 1.1 Загрузите данные. Файлы market_file.csv, market_money.csv, market_time.csv, money.csv

# %%
market_file= pd.read_csv('/datasets/market_file.csv')
market_money = pd.read_csv('/datasets/market_money.csv')
market_time = pd.read_csv('/datasets/market_time.csv')
money = pd.read_csv('/datasets/money.csv', sep=';', decimal = ',')

# %%
market_file.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
market_file.describe()
# Out:
#                   id  Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# count    1300.000000         1300.000000           1300.000000   1300.000000
# mean   215997.500000            4.253769              4.011538    601.898462
# std       375.421985            1.014814              0.696868    249.856289
# min    215348.000000            0.900000              3.000000    110.000000
# 25%    215672.750000            3.700000              4.000000    405.500000
# 50%    215997.500000            4.200000              4.000000    606.000000
# 75%    216322.250000            4.900000              4.000000    806.000000
# max    216647.000000            6.600000              5.000000   1079.000000
#
#        Акционные_покупки  Средний_просмотр_категорий_за_визит  \
# count        1300.000000                           1300.00000
# mean            0.319808                              3.27000
# std             0.249843                              1.35535
# ...

# %% [markdown]
# В главном датафрейме видим, что потребуются преобразования типа данных (Акционные_покупки; Маркет_актив_6_мес). Вероятно еть дубли в типе сервиса (стандартТ). Проверим дальше.
# Датафрейм не имеет пропусков, что уже неплохо.

# %%
market_money.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_money.describe()
# Out:
#                   id        Выручка
# count    3900.000000    3900.000000
# mean   215997.500000    5025.696051
# std       375.325686    1777.704104
# min    215348.000000       0.000000
# 25%    215672.750000    4590.150000
# 50%    215997.500000    4957.500000
# 75%    216322.250000    5363.000000
# max    216647.000000  106862.200000

# %% [markdown]
# нужна смена типа данных в выручке и также видим, что нет пропусков.

# %%
market_time.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
market_time.describe()
# Out:
#                   id        минут
# count    2600.000000  2600.000000
# mean   215997.500000    13.336154
# std       375.349754     4.080198
# min    215348.000000     4.000000
# 25%    215672.750000    10.000000
# 50%    215997.500000    13.000000
# 75%    216322.250000    16.000000
# max    216647.000000    23.000000

# %% [markdown]
# Пропусков нет, есть дубли в периоде. Придется изучать более детально.

# %%
money.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
money.describe()
# Out:
#                   id      Прибыль
# count    1300.000000  1300.000000
# mean   215997.500000     3.996631
# std       375.421985     1.013722
# min    215348.000000     0.860000
# 25%    215672.750000     3.300000
# 50%    215997.500000     4.045000
# 75%    216322.250000     4.670000
# max    216647.000000     7.430000

# %% [markdown]
# Пропусков нет, тип данных ок. Скорее тут не нужны будут никакие правки.

# %% [markdown]
# - 1.2 Проверьте, что данные в таблицах соответствуют описанию. Исследованием и объединением данных вы займётесь позже.

# %% [markdown]
# Как видим из данных выше, то датафреймы соответствуют описаниям, не имеют пропусков, однако нужно будет провреить их на наличие дубликатов и привести некоторые столбцы к корректному типу данных.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# - 2.1 Проведите необходимую предобработку данных. Названия столбцов можно оставить кириллическими.

# %%
market_file.columns = market_file.columns.str.lower()
market_file.columns = market_file.columns.str.replace(' ', '_')

columns_market_file =['покупательская_активность' ,'тип_сервиса', 'разрешить_сообщать', 'популярная_категория']
check_unique_values(market_file, columns_market_file)

market_file.loc[market_file['тип_сервиса'] == 'стандартт', 'тип_сервиса'] = 'стандарт'

columns_market_changing = {'маркет_актив_6_мес': float, 'акционные_покупки': float}
change_column_types(market_file, columns_market_changing)
# Out:
# Снизилась
# Прежний уровень
#
# премиум
# стандартт
# стандарт
#
# да
# нет
#
# Товары для детей
# Домашний текстиль
# Косметика и аксесуары
# Техника для красоты и здоровья
# Кухонная посуда
# Мелкая бытовая техника и электроника

# %%
market_file.head(n=5)
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась    стандарт                нет
# 3  215351                 Снизилась    стандарт                 да
# 4  215352                 Снизилась    стандарт                нет
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# В market_file поправили названия столбцов; убрали дубликаты; поменяли тип данных. В остальном датафрейм готов к исследованиям.

# %%
market_money['Период'].unique()
# Out:
# array(['препредыдущий_месяц', 'текущий_месяц', 'предыдущий_месяц'],
#       dtype=object)

# %%
columns_money_changing = {'Выручка': float}
change_column_types(market_money, columns_money_changing)

# %%
market_money.columns = market_money.columns.str.lower()

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# В датасете market_money отредактировали только тип данных и названия столбцов.

# %%
market_time['Период'].unique()
# Out:
# array(['текущий_месяц', 'предыдцщий_месяц'], dtype=object)

# %%
market_time.columns = market_time.columns.str.lower()
market_time['период'] = market_time['период'].replace('предыдцщий_месяц', 'предыдущий_месяц')

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %% [markdown]
# В датасете market_time нужно было отредактировать только названия столбцов и исправить опечату в значении столбца.

# %%
money.columns = money.columns.str.lower()

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# В датасете money нужно было отредактировать только названия столбца.

# %% [markdown]
# **Промежуточный вывод по этапу предобработки:**
#
# - В датафрейме market_file были приведены к корректному виду названия столбцов, убраны дубликаты, заменены типы данных в 2-х столбцах.
# - В датафрейме market_money были приведены к корректному виду названия столбцов, заменены типы данных.
# - В датафрейме market_time были приведены к корректному виду названия столбцов.
# - В датафрейме market_time были приведены к корректному виду названия столбцов.
#
# Во всех датафреймах не было пропусков. Данные собраны отлично на данном этапе. Собрал функции, но они оказались не очень сильно нужны, так как по сути косяков почти и не было. Везде применили змеинный регистр, убрали пробелы лишние; поменяли типы данных на флоат  вместо объектов, были дубли в первом датафрейме.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# - 3.1 Проведите исследовательский анализ данных из каждой таблицы. Отберите клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Оформите выводы по результатам шага.

# %%
activity_columns = ['покупательская_активность', 'тип_сервиса', 'разрешить_сообщать', 
                    'популярная_категория', 'маркет_актив_тек_мес']
plot_activity_distribution(market_file, 'id', activity_columns)

# %% [markdown]
# На графике выше я решил проверить распределение категориальных данных  в основном датасете:
#  - покупательская_активность снизилась у 38,3% клиентов. Достаточно высокий показатель. Бизнесу явно нужно что-то с этим делать.
#  - премиум сервисом пользуются 28,9% от всей выборки клиентов. Это неплохой показатель.
#  - На удивление 74% клиентов дают согласие на рассылки по товару. Думаю такой высокий уровень был получен какой-то скидкой за согласие)
#  - Распределение популярых категорий выглядит следующим образом:
#   - товары для детей: 25,4%
#   - домашний текстиль 19,3%
#   - косметика и аксесуары 17,2%
#   - техника для красоты и здоровья 14,2%
#   - мелкая бытовая техника и электроника 13,4%
#   - кухонная посуда 10,6%
#  - Маркетинговая активность в текущем месяце у половины клиентов составляет 4 штуки. У 24.8% 5 коммуникаций и 23.7% 3 коммуникации.
#  Делать каких-либо выводов еще нет оснований.

# %%
chart_hist(market_file, 'маркет_актив_6_мес', 'покупательская_активность')

# %% [markdown]
# Видим, что покупательская активность держится лучше у тех, кто участвует в маркетинговых активностях более 4-х раз за полгода, так же на ящике видны выбросы тех, кто менее 2-х раз поподал на маркетинговую коммуникацию. Стоит их глянуть более подробно.

# %%
market_file[market_file['маркет_актив_6_мес'] < 2.4]
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 30    215378                 Снизилась    стандарт                 да
# 32    215380                 Снизилась     премиум                нет
# 38    215386                 Снизилась    стандарт                 да
# 47    215395                 Снизилась     премиум                 да
# 55    215403                 Снизилась     премиум                 да
# 61    215409                 Снизилась     премиум                 да
# 63    215411                 Снизилась    стандарт                 да
# 70    215418                 Снизилась    стандарт                нет
# 81    215429                 Снизилась     премиум                нет
# 108   215456                 Снизилась    стандарт                 да
# 129   215477                 Снизилась    стандарт                нет
# 143   215491                 Снизилась    стандарт                 да
# ...

# %% [markdown]
# Лишь у двоих покупательская активность сохранилась на прежнем уровне. Реклама - двигатель прогресса.

# %%
chart_hist(market_file, 'длительность', 'покупательская_активность')

# %% [markdown]
# То, как давно клиент зарегестрирован не говорит о том, что он будет более активным. Скорее вначале даже более активные клиенты. Вероятнее их привлекают различными акциями и скидками мотивируя совершать покупки.

# %%
chart_hist(market_file, 'акционные_покупки', 'покупательская_активность')

# %% [markdown]
# Клиенты, которые приобретают товары невзирая на скидки сохраняют сввою активность. А вот те, кто покупает чисто по скидкам сильно просели в активности. Видимо черная пятница позади, вернуться через год.

# %%
market_file[market_file['акционные_покупки'] > 0.5]
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1     215349                 Снизилась     премиум                 да
# 3     215351                 Снизилась    стандарт                 да
# 4     215352                 Снизилась    стандарт                нет
# 14    215362                 Снизилась     премиум                 да
# 16    215364                 Снизилась     премиум                 да
# ...      ...                       ...         ...                ...
# 1254  216602           Прежний уровень    стандарт                нет
# 1256  216604           Прежний уровень    стандарт                 да
# 1257  216605           Прежний уровень    стандарт                 да
# 1292  216640           Прежний уровень    стандарт                нет
# 1299  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 1                    4.4                     4           819
# ...

# %%
chart_hist(market_file, 'средний_просмотр_категорий_за_визит', 'покупательская_активность')

# %% [markdown]
# Те, кто скроллит пару категорий как праивло проявляют снижение активности. (Оно и логично. нельзя покупать себе одни лишь айфоны).

# %%
chart_hist(market_file, 'неоплаченные_продукты_штук_квартал', 'покупательская_активность')

# %% [markdown]
# У клиентов, которые в корзине держат более 5 товаров видимо просто нет средств их приобретать и они откалывадют их туда не планируя приобретать ближайшее время.

# %%
chart_hist(market_file, 'ошибка_сервиса', 'покупательская_активность')

# %%
chart_hist(market_file, 'ошибка_сервиса', 'тип_сервиса')

# %% [markdown]
# Сайт любит падать.  4 ошибки за  сессию это больно. Срочно нужно набирать команду разрабов)

# %%
chart_hist(market_file, 'страниц_за_визит', 'покупательская_активность')

# %% [markdown]
# Ну как и в показателе со средними значениями: чем меньше клиент посещает категорий, тем более вероятно он не будет закупаться постоянно.

# %% [markdown]
#  - Смотрим вспомогательные таблицы и данные в них:

# %%
activity_columns =['период']
plot_activity_distribution(market_money, 'id', activity_columns)

# %%
revenue_by_month = market_money.groupby('период')['выручка'].sum()

plt.figure(figsize=(10, 6))
plt.plot(revenue_by_month.index, revenue_by_month.values, marker='o')
plt.title('Выручка по месяцам')
plt.xlabel('Месяц')
plt.ylabel('Выручка')
plt.xticks
plt.show()

# %%
chart_hist(market_money, 'выручка', None)

# %%
market_money_red = market_money[market_money['выручка']<100000]

# %%
chart_hist(market_money_red, 'выручка', None)

# %%
market_money[market_money['выручка']>100000]
# Out:
#         id         период   выручка
# 98  215380  текущий_месяц  106862.2

# %%
market_file[market_file['id']== 215380]
# Out:
#         id покупательская_активность тип_сервиса разрешить_сообщать  \
# 32  215380                 Снизилась     премиум                нет
#
#     маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 32                 1.7                     4           637               0.94
#
#               популярная_категория  средний_просмотр_категорий_за_визит  \
# 32  Техника для красоты и здоровья                                    3
#
#     неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит
# 32                                   2               4                 7

# %% [markdown]
# Найден выброс покупателя на 100к. Не шарю за технику для красоты, но наверное это какой-то новый дайсон) Выбросом считать его нельзя. Пока что убирать не буду, но возможно вернусь к этому шагу в дальнейшем и все же избавлюсь от этой строки. Не считая его распределение нормалное, но смещено чуть право. Чаще клиенты тратят 5к, а все что меньше 3.5к или больше 6.5к уже выбивается из межквартильного размаха. Однако выручка может быть любой и это не является выбросами, даже когда они в 10 раз выше других.
#
# Распределение  по месяцам одинаковое, а вот выручка в текущем месяце на 500к превосходит предпредыдущий (не знаю почему график построился именно так, но ладно, не мешает)

# %%
market_money= market_money[market_money['выручка']<100000]
market_money.describe()
# Out:
#                   id     выручка
# count    3899.000000  3899.00000
# mean   215997.658374  4999.57743
# std       375.243472   706.99988
# min    215348.000000     0.00000
# 25%    215673.000000  4590.10000
# 50%    215998.000000  4957.00000
# 75%    216322.500000  5363.00000
# max    216647.000000  7799.40000

# %%
activity_columns =['период']
plot_activity_distribution(market_time, 'id', activity_columns)

# %%
market_time.groupby('период')['минут'].sum()
# Out:
# период
# предыдущий_месяц    17508
# текущий_месяц       17166
# Name: минут, dtype: int64

# %%
chart_hist(market_time, 'минут', None)

# %% [markdown]
# Времени из месяца в месяц проводят одинаково, странно почему так сильно снижена активность покупателей.

# %%
chart_hist(money, 'прибыль', None)

# %% [markdown]
# Что такое значение прибыли непонятно, но наблюдаются выбросы. Есть схожесть с выбросами по выручке. Вероятно придется все же убирать их из датасетов, но пка что все же оставим.

# %% [markdown]
# По заднию проекта нам требовалось убрать тех, кто не покупал ничего за последние 3 месяца. Приступим к этому.

# %%
market_money = market_money.groupby('id').filter(lambda x: (x['период'].nunique() == 3) & (x['выручка'].min() > 0))

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3888 entries, 3 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3888 non-null   int64
#  1   период   3888 non-null   object
#  2   выручка  3888 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 121.5+ KB

# %% [markdown]
# Таких всего было трое. Мы с ними попрощались

# %% [markdown]
# **Промежуточный вывод по этапу исследовательского анализа данных**
#  - В датафрейме market_file:
#    - покупательская_активность снизилась у 38,3% клиентов. показатель высокий и явно нужно в этом разбираться;
#    - тип_сервиса стандартный у 71,1% клиентов. Премиумом пльзуются 28,9%. Достаточно высокий уровень.
#    - разрешить_сообщать. 74% клиентов дают согласие на рассылки по товару. Думаю такой высокий уровень был получен какой-то скидкой за согласие.
#    - Распределение популярых категорий выглядит следующим образом:
#      - товары для детей: 25,4%
#      - домашний текстиль 19,3%
#      - косметика и аксесуары 17,2%
#      - техника для красоты и здоровья 14,2%
#      - мелкая бытовая техника и электроника 13,4%
#      - кухонная посуда 10,6%
#    - маркетинговая_активность в текущем месяце у половины клиентов составляет 4 штуки. У 24.8% 5 коммуникаций и 23.7% 3 коммуникации.
#    - Исследовав данные по маркетинговой активности за 6 месяцев видим, что покупательская активность держится лучше у тех, кто участвует в маркетинговых активностях более 4-х раз за полгода, так же на ящике видны выбросы тех, кто менее 2.4-х раз попадал на маркетинговую коммуникацию. Если глянуть список, то видно, что почти все они менее активные покупатели.
#    - По данным столбца длительности заметно, что то, как давно клиент зарегестрирован не говорит о том, что он будет более активным. Скорее вначале даже более активные клиенты. Вероятнее их привлекают различными акциями и скидками мотивируя совершать покупки.
#    - По данным акционных покупок заметили, что те, тко приобретают товары невзирая на скидки сохраняют сввою активность. А вот те, кто покупает чисто по скидкам сильно просели в активности. Любителей сэкономить 168 штук насчиталось.
#    - По данным столбца со значениями среднего кол-ва просмотренных категорий за визит видим, что те, кто скроллит пару категорий как праивло проявляют снижение активности.
#    - По данным неоплаченных товаров в корзине за квартал видим, что у менее заинтерсованных покупателей в корзине лежит гораздо больше товаров. Активная аудитория имеет не более 5 товаров. Неактивная же любит сложить в корзину побольше
#    - Сайт часто руинится. Люди которые ловят 2-4 ошибку выходят из сервиса.
#    - Всего проскролленых страниц с клиентом показывает аналогичные со средними результаты: чем меньше клиент посещает категорий, тем более вероятно он не будет закупаться постоянно.
#  - В датафрейме market_money:
#    - Распределения покупок по месяца одинаковые
#    - Выручка от месяца к месяцу растет, несомтря на снижение активности. Порядка 6.27 в препредыдущем; затем 6.41 в предыдщуем и свыше 6.9 в текущем месяце.
#    - Есть какой-то прем клиент, который купил товар более, чем за сотню.
#    - Чаще клиенты тратят 5к, а все что меньше 3.5к или больше 6.5к уже выбивается из межквартильного размаха. Убрали 1 выброс, с выручкой более, чем 100к.
#  - В датафрейме market_time:
#    - Времени из месяца в месяц проводят одинаково.
#  - В датафрейме money:
#    - Значение прибыли имеет нормальное распределение, на ящике виднеются выбросы, похожи на те, что есть и в датасете выше по выручке. Не удаляем их.

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# - 4.1 Объедините таблицы market_file.csv, market_money.csv, market_time.csv. Данные о прибыли из файла money.csv при моделировании вам не понадобятся.
#
# Учитывайте, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделайте отдельный столбец для каждого периода.

# %%
market_money.head()
# Out:
#        id               период  выручка
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6
# 5  215349     предыдущий_месяц   5216.0
# 6  215350  препредыдущий_месяц   4826.0
# 7  215350        текущий_месяц   5058.4

# %%
market_money['выручка_текущий_месяц'] = market_money.loc[market_money['период'] == 'текущий_месяц', 'выручка']
market_money['выручка_предыдущий_месяц'] = market_money.loc[market_money['период'] == 'предыдущий_месяц', 'выручка']   
market_money['выручка_препредыдущий_месяц'] = market_money.loc[market_money['период'] == 'препредыдущий_месяц', 'выручка']   
drop_columns=['период', 'выручка']
market_money= market_money.drop(drop_columns, axis =1)
market_money = market_money.groupby('id') .agg ({'выручка_текущий_месяц':'first', 'выручка_предыдущий_месяц':'first',
                                                 'выручка_препредыдущий_месяц':'first' })
market_money.head()
# Out:
#         выручка_текущий_месяц  выручка_предыдущий_месяц  \
# id
# 215349                 4971.6                    5216.0
# 215350                 5058.4                    5457.5
# 215351                 6610.4                    6158.0
# 215352                 5872.5                    5807.5
# 215353                 5388.5                    4738.5
#
#         выручка_препредыдущий_месяц
# id
# 215349                       4472.0
# 215350                       4826.0
# 215351                       4793.0
# 215352                       4594.0
# 215353                       5124.0

# %%
market_time['период_текущий_месяц'] = market_time.loc[market_time['период'] == 'текущий_месяц', 'минут']
market_time['период_предыдущий_месяц'] = market_time.loc[market_time['период'] == 'предыдущий_месяц', 'минут']
drop_columns=['период', 'минут']
market_time= market_time.drop(drop_columns, axis =1)
market_time = market_time.groupby('id') .agg ({'период_текущий_месяц':'first', 'период_предыдущий_месяц':'first'})

market_time.head()
# Out:
#         период_текущий_месяц  период_предыдущий_месяц
# id
# 215348                  14.0                     13.0
# 215349                  10.0                     12.0
# 215350                  13.0                      8.0
# 215351                  13.0                     11.0
# 215352                  11.0                      8.0

# %%
data = pd.merge(pd.merge(market_file, market_money, on='id'), market_time, on='id')
data
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0     215349                 Снизилась     премиум                 да
# 1     215350                 Снизилась    стандарт                нет
# 2     215351                 Снизилась    стандарт                 да
# 3     215352                 Снизилась    стандарт                нет
# 4     215353                 Снизилась    стандарт                 да
# ...      ...                       ...         ...                ...
# 1291  216643           Прежний уровень    стандарт                 да
# 1292  216644           Прежний уровень    стандарт                нет
# 1293  216645           Прежний уровень    стандарт                 да
# 1294  216646           Прежний уровень    стандарт                 да
# 1295  216647           Прежний уровень     премиум                 да
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 0                    4.4                     4           819
# ...

# %% [markdown]
# Это почему-то было невреоятно сложно. Собрали итоговый датасет с информацией о выручке по месяцам и проведенном времени по месяцам.

# %% [markdown]
# ## Корреляционный анализ

# %% [markdown]
# - 5.1 Проведите корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделайте выводы о мультиколлинеарности и при необходимости устраните её.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1296 entries, 0 to 1295
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1296 non-null   int64
#  1   покупательская_активность            1296 non-null   object
#  2   тип_сервиса                          1296 non-null   object
#  3   разрешить_сообщать                   1296 non-null   object
#  4   маркет_актив_6_мес                   1296 non-null   float64
#  5   маркет_актив_тек_мес                 1296 non-null   int64
#  6   длительность                         1296 non-null   int64
#  7   акционные_покупки                    1296 non-null   float64
#  8   популярная_категория                 1296 non-null   object
#  9   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1296 non-null   int64
# ...

# %%
data.describe()
# Out:
#                   id  маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# count    1296.000000         1296.000000           1296.000000   1296.000000
# mean   215999.464506            4.256404              4.009259    602.967593
# std       374.327860            1.013525              0.696316    249.195823
# min    215349.000000            0.900000              3.000000    121.000000
# 25%    215675.750000            3.700000              4.000000    409.500000
# 50%    215999.500000            4.200000              4.000000    606.500000
# 75%    216323.250000            4.900000              4.000000    806.250000
# max    216647.000000            6.600000              5.000000   1079.000000
#
#        акционные_покупки  средний_просмотр_категорий_за_визит  \
# count        1296.000000                          1296.000000
# mean            0.320069                             3.267747
# std             0.249159                             1.355125
# ...

# %%
correlation_matrix = data.corr(method='spearman')
plt.figure(figsize=(10, 8))
sns.set(style='white')
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
phik_matrix = data.phik_matrix()

plt.figure(figsize=(10, 8))
sns.heatmap(phik_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title("Корреляционная матрица")
plt.show()
# Out:
# interval columns not set, guessing: ['id', 'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'выручка_текущий_месяц', 'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'период_текущий_месяц', 'период_предыдущий_месяц']

# %% [markdown]
# Матрица дикая получилась конечно... Видим на ней, что целевой признак (покупательская_активность) коррелирует с тем, сколько страниц за визит клиенты листают, а также сколько времени проводили в предыдущий месяц и текущий. Причем в текущем корреляция уже ниже, хотя это странно.В остальном корреляция слабая между признаками, даже как-то слишком сильно. Линейная модель тут похоже даст промах хехе.

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# Примените все изученные модели. Для этого используйте пайплайны.

# %% [markdown]
# Сперва подготовим данные для обучения моделей.

# %% [markdown]
# Проверим наличие дисбаланса классов, так как перед нами стоит задача бинарной классификации.

# %%
data['покупательская_активность'].value_counts(normalize=True)
# Out:
# Прежний уровень    0.618827
# Снизилась          0.381173
# Name: покупательская_активность, dtype: float64

# %%
data['покупательская_активность'].value_counts(normalize=True).plot(kind='bar')
plt.title('Дисбаланс классов')
plt.xlabel('Активность')
plt.ylabel('Объем')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# В идеале ожидаем 1:1. У нас датасет по сути разбит чуть ли не в пропорции 2:1.
# - Мажорный класс - прежний_уровень;
# - Минорный класс - снизилась.
#
# Таким образом нуно провести стратификацию данных при их подготовке.

# %%
RANDOM_STATE=42

X = data.drop(['покупательская_активность', 'id'], axis=1)
y= data['покупательская_активность']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=RANDOM_STATE, stratify=y)

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4))

y.value_counts().plot(kind='bar', ax=ax[0], rot=0)
ax[0].set_title("Исходный датасет")
y_train.value_counts().plot(kind='bar', ax=ax[1], rot=0)
ax[1].set_title("Train")
y_test.value_counts().plot(kind='bar', ax=ax[2], rot=0)
ax[2].set_title("Test")

plt.show()

# %% [markdown]
# - 6.1 Во время подготовки данных используйте ColumnTransformer.
#
#  - Количественные и категориальные признаки обработайте в пайплайне раздельно.
#  - Для кодирования категориальных признаков используйте как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.

# %% [markdown]
# Начинаем собирать пайплайн:

# %%
ohe_columns = ['популярная_категория']
ord_columns = ['тип_сервиса', 'разрешить_сообщать']

num_columns = ['маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',  
               'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 
               'ошибка_сервиса','страниц_за_визит', 'акционные_покупки',
               'период_текущий_месяц', 'период_предыдущий_месяц',
              'выручка_текущий_месяц', 'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц']

# %%
ohe_pipe = Pipeline(
    [
        (
           'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
        'ohe',
            OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)
        )
    ]
)

# %%
ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord',
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
             OrdinalEncoder(
                 categories=[
                    ['стандарт', 'премиум'],
                    ['да', 'нет']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# Объединили шаги подготовки, применяем пайп лайн ohe_pipe и ord_pipe. Масштабируем данные num_columns и  minmax_columns.В условиях задачи требовалось использовать 2 кодировщика и 2 скайлера. При этом при исопльзовании нормальизации пришлось юзать make_column_transformer вместо ColumnTransformer.

# %% [markdown]
# - 6.2 Обучите четыре модели: KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и  SVC().
#
#  - Для каждой из них подберите как минимум один гиперпараметр.
#  - Выберите подходящую для задачи метрику, аргументируйте свой выбор. Используйте эту метрику при подборе гиперпараметров.

# %%
pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь для модели SVC()
    #{
    #  'models': [SVC(random_state=RANDOM_STATE, kernel='poly')],
    #    'models__degree': range(2, 3),
    #    'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    #}
]

# %% [markdown]
# Наиболее подходящей метрикой в нашем случае будет естественно roc-auc. Она отражает зависимость TPR и FPR, поэтому она всегда даёт адекватную оценку качества модели.
# К примеру, f1 покажет низкое качество если хотя бы одна из его составляющих даёт низкую оценку. Для accuracy важно только общее количество правильных ответов, поэтому она не обращает внимания на то, что модель плохо предсказывает принадлежность к минорным классам. Поэтому эту метрику нельзя использовать при дисбалансе.

# %% [markdown]
# - 6.3 Выберите лучшую модель, используя заданную метрику. Для этого примените одну из стратегий:
#  - Использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель самостоятельно;
#  - Использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернёт вам лучшую модель.

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=15, 
    scoring='roc_auc',
    n_jobs=-1,
    random_state=RANDOM_STATE
)
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=10,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first',
#                                                                                                               handle_unknown='ignore',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['популярная_категория']),
#                                                  ('ord',
# ...

# %%
y_test_pred = randomized_search.predict(X_test)
y_test_proba = randomized_search.predict_proba(X_test)
print(f'Метрика ROC-AUC на тестовой выборке: {round(roc_auc_score(y_test, y_test_proba[:,1]), 2)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.92

# %% [markdown]
# Промежуточный вывод по итогу перебора моделей с помощью пайплайнов:
#  - Лучшей моделью из перебора оказалсь модель линейной регрессии. с параметрами :
#   - C=4 (параметр обратной силы регуляризации. Большие значения C означают меньшую регуляризацию, что позволяет модели более гибко подстраиваться под данные. В данном случае значение C=4 указывает на относительно слабую регуляризацию.)
#   - penalty='l1' (тип регуляризации. Здесь l1 обозначает L1 регуляризацию, которая добавляет штраф к абсолютным значениям коэффициентов модели во время обучения. Это позволяет модели выполнить отбор признаков, установив важные признаки на нулевые значения.)
#   - random_state=42 (просто константа)
#   - solver='liblinear' (то один из алгоритмов оптимизации, реализованных в библиотеке scikit-learn. Он обычно используется для задач двоичной классификации и хорошо работает на средних и больших наборах данных.)
#  - Рок аук выдает 0.92, что является очень неплохом результатом.

# %% [markdown]
# ## Анализ важности признаков

# %% [markdown]
# Для начала выведем датафрейм с прогнозом и его вероятностью по каждому из клиентов. Для этого возьмем лучшую модель, которую перебрал наш пайплайн.

# %%
X_combined = pd.concat([X_train, X_test])
y_combined = pd.concat([y_train, y_test])

# %%
y_combined_pred = randomized_search.predict(X_combined)
predictions_df = pd.DataFrame(y_combined_pred, columns=["прогноз"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_98/1772346856.py in <module>
# ----> 1 y_combined_pred = randomized_search.predict(X_combined)
#       2 predictions_df = pd.DataFrame(y_combined_pred, columns=["прогноз"])
#
# NameError: name 'randomized_search' is not defined

# %%
y_combined_prob_class1 = randomized_search.predict_proba(X_combined)[:, 1]
prob_class1_df = pd.DataFrame(y_combined_prob_class1, columns=["вероятность_снижения"])

# %%
data['прогноз'] = predictions_df
data['вероятность_снижения'] = prob_class1_df
data.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %%
X_train_2 = pipe_final.named_steps['preprocessor'].fit_transform(X_train)
X_test_2 = pipe_final.named_steps['preprocessor'].transform(X_test)
feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()
X_test_2 = pd.DataFrame(X_test_2, columns=feature_names)
explainer = shap.LinearExplainer(randomized_search.best_estimator_.named_steps['models'], X_train_2)
shap_values = explainer(X_test_2)

# %% [markdown]
# - 7.1 Оцените важность признаков для лучшей модели и постройте график важности с помощью метода SHAP.

# %%
shap.plots.beeswarm(shap_values, max_display=15)

# %% [markdown]
# Данный график отражает общую важность признаков модели по значениям Шепли, присвоенным всем наблюдениям в выборке.
#
# По данному графику негативные значения Шепли слева от центральной вертикальной линии означают, что признак склоняет модель отнести объекты к классу 0, а положительные справа — к классу 1.
#
# Чем толще линия по вертикали, тем больше наблюдений сгруппированы вместе: у них близкие значения Шепли. Это значит, что модель уверенно присваивает SHAP-значения, с учётом закономерностей в данных.
#
# Цвет точки отражает значения каждого признака объекта: чем краснее объект, тем значение признака выше
#
# - Наибольшую значимость  несут признаки расположенные ближе к концу оси X.
#  (Страниц за визит; среднией просмотр категорий; время, проведенное в предыдущем периоде; кол-во продуктов в корзине за квартал; акционные покупки время в текущем месяце и, пожалуй, маркетинговая активность за полгода тоже.
#
# - Наименьшую значимость несут признаки, расположенные ближе к началу оси X.
#  (популярная категория; выручка за препредыдущий месяц; выручка за предыдущий месяц; длительность, ошибки сервиса, тип сервиса.)

# %%
shap.plots.waterfall(shap_values[5])

# %% [markdown]
# Для начала вспомним как верно читать данный график:
# 1. Начальная точка (базовое значение): График начинается с определенной базовой точки, которая соответствует предсказанию модели для некоторых начальных значений признаков, например, средним значениям признаков в тренировочном наборе данных.
# 2. Вклады признаков: Для каждого признака вклад отображается в виде столбика (горизонтального прямоугольника) на графике waterfall. Значение столбика откладывается на вертикальной оси и представляет вклад этого признака в общую предсказанную величину. Столбики могут быть положительными (синего цвета) или отрицательными (красного цвета).
# 3. Итоговая предсказанная величина отображается в виде вертикальной линии на графике. Она представляет изменение предсказания модели относительно базовой точки, накопленное влияние всех признаков.
# 4. Направление вклада: Если вклад признака положительный (синий столбик), это значит, что данный признак увеличивает предсказание относительно базовой точки. Если вклад отрицательный (красный столбик), это значит, что данный признак уменьшает предсказание относительно базовой точки.
# 5. Сумма вкладов: Сумма всех вкладов признаков будет равна итоговому изменению предсказания модели относительно базовой точки. Она может быть положительной или отрицательной, что указывает на увеличение или уменьшение предсказанной величины относительно базовой точки.
#
#  График waterfall помогает понять, какие признаки и насколько вносят вклад в изменение предсказания модели. Он позволяет проанализировать наиболее важные признаки и понять их положительное или отрицательное влияние на предсказание.
#
#  Как мы можем увидеть 5 важнейших признаков это средний просмотр категорий за визит, проведенное время за предыдущий месяц, маркетинговая активность за полгода, кол-во страниц за визит,  выручка за текущий месяц;

# %%
shap.plots.bar(shap_values, max_display=20, show=False)
plt.title('График общей значимости признаков', size=15)
plt.show()

# %% [markdown]
# Здесь название графика говорит само за себя. Самыми важными признаками для построения модели были:
# - кол-во страниц за визит;
# - среднее кол-во просмотренных категорий за визит;
# - проведенное в предыдущем месяце время;
# - проведенное в текущем месяце время;
# - доля акционных покупок.
#
# В общем-то если перенести данных в жизнь, то вполне верится.

# %% [markdown]
# Посмотрим на матрицу ошибок

# %%
cm = confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('Реальные значения')
plt.xlabel('Предсказания');

# %% [markdown]
# - 7.2 Сделайте выводы о значимости признаков:
#
#  - какие признаки мало значимы для модели;
#  - какие признаки сильнее всего влияют на целевой признак;
#  - как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.

# %% [markdown]
# - Для итоговой модели которую мы отобрали наиболее важными признаками является:
#  1. кол-во страниц за визит;
#  2. среднее кол-во просмотренных категорий за визит;
#  3. проведенное в предыдущем месяце время;
#  4. кол-во неоплаченных товаров в корзине за квартал;
#  5. доля акционных покупок.
# - Наименее важны оказались следующие признаки:
#  1. выручка за текущий месяц;
#  2. популярные категории (за исключением бытовой техники и техники для красоты;
#  3. разрешение на отправку рекламынх рассылок;
#  4. тип сервиса;
#  5. выручки за предыдущий месяц;
#  6. ошибки сервиса;
#  7. длительность.
# - Для принятия каких-либо решений от бизнеса стоит обращать внимание на поведение клиента на сайте, стоит увеличивать вовлеченность клиентов: то сколько они скроллят страницы; как хорошо им предлагается новые категории товаров. Проведение скидок.

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# - 8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.

# %%
data = data.merge(money, on='id', how='inner')

# %%
data.sample(n=1)
# Out:
#         id покупательская_активность тип_сервиса разрешить_сообщать  \
# 83  215435                 Снизилась     премиум                 да
#
#     маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 83                 4.8                     4           875               0.35
#
#    популярная_категория  средний_просмотр_категорий_за_визит  ...  \
# 83     Товары для детей                                    2  ...
#
#     ошибка_сервиса  страниц_за_визит  выручка_текущий_месяц  \
# 83               5                 9                 7605.3
#
#     выручка_предыдущий_месяц  выручка_препредыдущий_месяц  \
# 83                    6869.5                       5008.0
#
#     период_текущий_месяц  период_предыдущий_месяц    прогноз  \
# 83                  11.0                      7.0  Снизилась
#
#    вероятность_снижения  прибыль
# 83             0.961354     3.24
#
# [1 rows x 21 columns]

# %% [markdown]
# Вспоминая диаграмму Исикавы будем исследовать признаки коммуникации с клиентом: тип сервиса; разрешение на рассылки; маркетинг за полгода; маркетинг текущего месяца, а также длительность истории с клиентом.

# %%
scatplt(data, 'прибыль', 'тип_сервиса')
scatplt(data, 'прибыль', 'маркет_актив_6_мес')
scatplt(data, 'прибыль', 'маркет_актив_тек_мес')
scatplt(data, 'прибыль', 'длительность')

# %% [markdown]
# На мой взгляд клиентов нужно сегментировать по  прибыльности и вероятности снижения их покупательской активности. Какой-то линейной связи не наблюдается по признакам.
#
# Для начала разобьем их на 4 сегмента:
#  1. Клиенты, с низкой вероятностью снижения активности и низкой прибылью;
#  2. Клиенты, с низкой вероятностью снижения активности и высокой прибылью;
#  3. Клиенты, с высокой вероятностью снижения активности и низкой прибылью;
#  4. Клиенты, с высокой вероятностью снижения активности и высокой прибылью.
# - Низкой вероятностью будем счиатать показатель < 0.65;
# - Низкой прибылью удем считать показатель < 4.

# %%
stable_low = data.loc[(data['вероятность_снижения'] < 0.65) & (data['прибыль'] < 4)]
stable_hight = data.loc[(data['вероятность_снижения'] < 0.65) & (data['прибыль'] >= 4)]

unstable_low = data.loc[(data['вероятность_снижения'] >= 0.65) & (data['прибыль'] < 4)]
unstable_hight = data.loc[(data['вероятность_снижения'] >= 0.65) & (data['прибыль'] >= 4)]

# %% [markdown]
# - 8.2 Выберите группу покупателей и предложите, как увеличить её покупательскую активность:
#  - Проведите графическое и аналитическое исследование группы покупателей.
#  - Сделайте предложения по работе с сегментом для увеличения покупательской активности.

# %% [markdown]
# Самый важный сегмент из выделенных групп на мой взгляд это 4 группа: клиенты с высокой вероятностью снижения и высокой прибылью. Эту группу и будем исследовать. Проверим признаки, которые больше всего были оценены моделью.

# %%
pd.set_option('display.max_columns', None)
data.sample(n=1)
# Out:
#           id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1276  216628           Прежний уровень    стандарт                нет
#
#       маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# 1276                 3.8                     4           467
#
#       акционные_покупки                  популярная_категория  \
# 1276               0.22  Мелкая бытовая техника и электроника
#
#       средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# 1276                                    5                                   1
#
#       ошибка_сервиса  страниц_за_визит  выручка_текущий_месяц  \
# 1276               4                 4                 5225.0
#
#       выручка_предыдущий_месяц  выручка_препредыдущий_месяц  \
# 1276                    4458.0                       5200.0
#
#       период_текущий_месяц  период_предыдущий_месяц          прогноз  \
# 1276                  14.0                     18.0  Прежний уровень
#
# ...

# %%
scatplt(unstable_hight, 'прибыль', 'страниц_за_визит')
scatplt(unstable_hight, 'прибыль', 'средний_просмотр_категорий_за_визит')
scatplt(unstable_hight, 'прибыль', 'период_предыдущий_месяц')
scatplt(unstable_hight, 'прибыль', 'неоплаченные_продукты_штук_квартал')
scatplt(unstable_hight, 'прибыль', 'акционные_покупки')
scatplt(unstable_hight, 'прибыль', 'выручка_препредыдущий_месяц')

# %%
print("Среднее кол-во страниц за визит у клиентов с высокой вероятностью снижения покупательской активности:", round(unstable_hight['страниц_за_визит'].mean(), 2))
print("Среднее кол-во страниц за визит у клиентов с низкой вероятностью снижения покупательской активности:", round(stable_hight['страниц_за_визит'].mean(), 2))
print("Среднее кол-во категорий за визит у клиентов с высокой вероятностью снижения покупательской активности:", round(unstable_hight['средний_просмотр_категорий_за_визит'].mean(), 2))
print("Среднее кол-во категорий за визит у клиентов с низкой вероятностью снижения покупательской активности:", round(stable_hight['средний_просмотр_категорий_за_визит'].mean(), 2))
print("Среднее кол-во минут в предыдущем месяце у клиентов с высокой вероятностью снижения покупательской активности:", round(unstable_hight['период_предыдущий_месяц'].mean(), 2))
print("Среднее кол-во минут в предыдущем месяце у клиентов с низкой вероятностью снижения покупательской активности:", round(stable_hight['период_предыдущий_месяц'].mean(), 2))
print("Среднее кол-во продуктов в корзине у клиентов с высокой вероятностью снижения покупательской активности:", round(unstable_hight['неоплаченные_продукты_штук_квартал'].mean(), 2))
print("Среднее кол-во продуктов в корзине у клиентов с низкой вероятностью снижения покупательской активности:", round(stable_hight['неоплаченные_продукты_штук_квартал'].mean(), 2))
print("Среднее кол-во доли акционных товаров у клиентов с высокой вероятностью снижения покупательской активности:", round(unstable_hight['акционные_покупки'].mean(), 2))
print("Среднее кол-во доли акционных товаров у клиентов с низкой вероятностью снижения покупательской активности:", round(stable_hight['акционные_покупки'].mean(), 2))
# Out:
# Среднее кол-во страниц за визит у клиентов с высокой вероятностью снижения покупательской активности: 8.18
# Среднее кол-во страниц за визит у клиентов с низкой вероятностью снижения покупательской активности: 8.07
# Среднее кол-во категорий за визит у клиентов с высокой вероятностью снижения покупательской активности: 3.25
# Среднее кол-во категорий за визит у клиентов с низкой вероятностью снижения покупательской активности: 3.18
# Среднее кол-во минут в предыдущем месяце у клиентов с высокой вероятностью снижения покупательской активности: 13.64
# Среднее кол-во минут в предыдущем месяце у клиентов с низкой вероятностью снижения покупательской активности: 13.32
# Среднее кол-во продуктов в корзине у клиентов с высокой вероятностью снижения покупательской активности: 2.85
# Среднее кол-во продуктов в корзине у клиентов с низкой вероятностью снижения покупательской активности: 2.81
# ...

# %%
data['сегментация'] = data.apply( lambda row: 'Исследуемый сегмент' \
        if row['вероятность_снижения'] > 0.65 and row['прибыль'] > 4 \
        else 'Остальные пользователи', axis=1)

# %% [markdown]
# Глянем на коммуникации с клиентом:

# %%
chart_hist_(data, 'тип_сервиса', 'сегментация')
chart_hist_(data, 'разрешить_сообщать', 'сегментация')
chart_hist_(data, 'маркет_актив_6_мес', 'сегментация')
chart_hist_(data, 'маркет_актив_тек_мес', 'сегментация')
chart_hist_(data, 'длительность', 'сегментация')

# %% [markdown]
# На данных графиках видим, что выделенный сегмент клиентов, который является целевой аудиторией и с высокой долей вероятности снизит свои траты в маркетплейсе практически  отличается от остальной массы клиентов  маркетинговой активностью, а также разрешением предоставлять такую активность в принципе.

# %% [markdown]
# Посмотрим на продуктовое поведение клиентов и чем оно отличается.

# %%
chart_hist_(data, 'популярная_категория', 'сегментация', xlabel_rotation=45)
chart_hist_(data, 'средний_просмотр_категорий_за_визит', 'сегментация')
chart_hist_(data, 'неоплаченные_продукты_штук_квартал', 'сегментация')

# %% [markdown]
# Косметика и акссесуары, а также товары для детей наиболее предпочитетльные категории для исследуемой группы.
# Поведение по просмотренным категориям так же не очень сильно отличается. На что стоит обратить тут внимание это что кол-во товаров в коризне у них сильно меньше. Они не добавляют товар в коризну и поэтому не так сильно задаются целью купить его со следующей зарплаты.

# %% [markdown]
# Глянем на поведение клиентов на сайте.

# %%
chart_hist_(data, 'период_предыдущий_месяц', 'сегментация')
chart_hist_(data, 'период_текущий_месяц', 'сегментация')
chart_hist_(data, 'страниц_за_визит', 'сегментация')
chart_hist_(data, 'ошибка_сервиса', 'сегментация')

# %% [markdown]
# По поведению на сайте так же нет каки-либо сильно выбиывающихся наблюдений за исключением того, что они посещают мало страниц за визит

# %% [markdown]
# Глянем на финансовое поведение исследуемой группы:

# %%
#уберем челс со 100к,а то неудобно график читать. 
filtered_data = data.loc[data['выручка_текущий_месяц'] < 100000]

# %%
chart_hist_(filtered_data, 'выручка_текущий_месяц', 'сегментация')
chart_hist_(data, 'выручка_предыдущий_месяц', 'сегментация')
chart_hist_(data, 'выручка_препредыдущий_месяц', 'сегментация')

# %% [markdown]
# Нет каких-либо видимых различий исследуемого сегмента от остальных.

# %% [markdown]
# - 8.3 Сделайте выводы о сегментах:
#  - какой сегмент вы взяли для дополнительного исследования,
#  - какие предложения вы сделали и почему.

# %% [markdown]
# Не знаю насколько критично здесь было построение различных графиков и сравнений, но сегментация клиентов была по принципу вероятности снижения их покупательской активности и прибыльности. По итогу получилось 4 группы из которые наболее важно изучить ту, что приносит высокий доход, но при этом высока вероятность снижения их покупательской активности.
#  На основе сравнения этих клиентов с подобными по прибыльности, но с малой вероятностью снижения активности можно сказать, что
# проблема заключается по всем признакам, которые модель принимала как наиболее важные. Мы видим, что для того чтобы клиенты был таким же вовлеченным требуется увеличение страниц которые он скроллит. Это и логично: чем больше пролистал, тем больше вероятность найти что-то интересное для себя. Та же логика преследует нас и с кол-вом категорий, кол-во неоплаченных продуктов в коризне, проведенным временем на маркетплейсе и акционных товаров. Однако все эти признаки сами по себе очень слабо отличаются своми значениями, однако вкупе дают неутешительный прогноз.
#
# На мой взгляд нужно увеличивать вовлеченность клиентов в приложение, что потянет за собой почти все метрики, кроме акционных покупок. При этом развивать вовлеченность за счет скидок не лучшее решение с точки зрения бизнеса.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В начале проекта была проведена загрузка датасетов, после которой была изучена первоначальная информация о данных.
# Затем был выполнен этап предобработки данных, включающий изменение названий столбцов для удобства работы, удаление дубликатов и приведение типов данных к корректному формату.
# Исследовательский анализ данных позволил сделать следующие выводы:
# 38,3% клиентов снизили свою покупательскую активность, что является значительным показателем, требующим внимания и действий со стороны бизнеса.
# 28,9% клиентов используют премиум сервис, что является достаточно хорошим результатом.
# 74% клиентов соглашаются на рассылки по товару, возможно, под влиянием какой-то скидки или акции.
# Популярные категории товаров: товары для детей (25,4%), домашний текстиль (19,3%), косметика и аксессуары (17,2%), техника для красоты и здоровья (14,2%), мелкая бытовая техника и электроника (13,4%), кухонная посуда (10,6%).
# Более половины клиентов совершили 4 маркетинговых активности в текущем месяце, и пока еще нельзя сделать выводы из этого показателя.
# Клиенты, участвующие в маркетинговых активностях более 4 раз за полгода, сохраняют свою покупательскую активность, в то время как клиенты, участвующие менее 2 раз, сильно снижают свою активность.
# Вначале клиенты, зарегистрированные недавно, проявляют большую активность, но она с течением времени уменьшается.
# Клиенты, которые покупают независимо от скидок, сохраняют свою активность, в то время как те, кто покупает только по скидкам, снижают свою активность.
# Клиенты, которые просматривают несколько категорий товаров, обычно проявляют снижение активности.
# Клиенты, которые имеют более 5 товаров в корзине, скорее всего не планируют покупку этих товаров в ближайшее время.
# Сайт время от времени имеет ошибки и падает, что требует улучшения стабильности и работы команды разработчиков.
# Уровень активности клиентов ниже, если они посещают меньшее количество категорий.
# В датафрейме market_money обнаружено:
# Распределение покупок по месяцам одинаковое.
# Выручка от месяца к месяцу увеличивается, несмотря на снижение активности, что является положительным показателем.
# Имеется клиент, который купил товар на сумму более 100.
# Чаще всего клиенты тратят сумму около 5 тысяч, и те покупки, которые меньше 3,5 тысяч или больше
# При анализе данных были проведены этапы предобработки, исследовательского анализа и обработки данных.
# Проведенный исследовательский анализ позволил выявить интересные зависимости и закономерности в данных, такие как связь покупательской активности с маркетинговыми активностями, эффект использования премиум сервиса, популярные категории товаров и другие.
# Было выявлено, что наиболее важными признаками для предсказания оттока клиентов являются количество страниц за визит, среднее количество просмотренных категорий за визит, проведенное в предыдущем месяце время и количество неоплаченных товаров в корзине за квартал и доля акционных покупок. Наименее важными оказались признаки, такие как выручка за текущий месяц, разрешение на отправку рекламных рассылок, тип сервиса и другие.
# Построена модель логистической регрессии с гиперпараметрами C=2, penalty='l1', random_state=42, solver='liblinear', которая продемонстрировала хорошее качество с показателем ROC-AUC равным 92%. Данная метрика была выбрана потому что она подходид для бинарной классификации с дисбалансом классов.
# Произведена сегментация пользователей, и выделены подгруппы клиентов, которые приносят высокую прибыль, но имеют высокий риск ухода. Анализ позволил выявить проблему во всех признаках, которые модель определила как наиболее важные. Для улучшения вовлеченности клиентов в приложение рекомендуется увеличение количества пролистываемых страниц, количество просмотренных категорий, увеличение времени на маркетплейсе и стимулирование акционных покупок. Однако стоит отметить, что развивать вовлеченность клиентов за счет скидок не является наилучшим решением с точки зрения бизнеса.
# Разработчикам рекомендуется обратить внимание на количество ошибок в приложении, которое оказывает сильное влияние на показатели и качество работы сервиса.
#
# Проведенный анализ данных, построение модели и сегментация пользователей позволили выявить важные закономерности и предложить рекомендации для улучшения работы маркетплейса и удержания клиентов. На мой взгляд нужно увеличивать вовлеченность клиентов в приложение, что потянет за собой почти все метрики, кроме акционных покупок. При этом развивать вовлеченность за счет скидок не лучшее решение с точки зрения бизнеса.
# Для разрабов совет:  обратить внимание на кол-во ошибок. Мне кажется это огромный недочет и стоит обратить внимание.

# %%
Ссылка на мой GitHub https://github.com/Dmitriy696gr/yandex_project
